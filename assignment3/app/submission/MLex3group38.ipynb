# %% [markdown]
# ## ML 2020 Ex3 Group 38 jupyter notebook

# %%
# run this to create train/test data split from raw data
# %run "prepare.py" 7 3

# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport networks
# %aimport modules_multi
# %aimport utils

# %%
from networks import LogSoftMax, MLP, DAELayer, DAESoftMax, CNN
from modules_multi import buildModelMulti, invertModel
from modules_DAE import buildDAELayer, buildDAESoftmaxModel, invertDAE

# %%
buildModelMulti(LogSoftMax(), lRate=0.01, epochs=30, plot=True, save=True)
# Out:
# Starting at 17:10:01 to build LogSoftMax model...
# Finished at 17:10:07, duration in sec: 5

# %%
invertModel(LogSoftMax(), lrMod=0.001, lrInv=0.001, nStep=50, plot=True, save=True)
# Out:
# Starting at 17:12:07 to invert LogSoftMax...
# Finished at 17:12:10, duration in sec: 3
# SSM: mean 3.57e-05, std 1.82e-05
# NRMSE: mean 1.39e+01, std 8.97e+00

# %%
# MLP

# %%
# MLP

# %%
buildDAELayer(DAELayer(10304, 1000), lRate=1e-4, epochs=5000, plot=True)

# %%
buildDAELayer(DAELayer(1000, 300), lRate=1e-4, epochs=5000, plot=True)
# Out:
# Starting at 12:30:57 to build DAE_300 model...
# Finished at 12:31:00, duration in sec: 3

# %%
buildDAESoftmaxModel(DAESoftMax(), lRate=1e-2, epochs=200, plot=True)
# Out:
# Starting at 12:33:36 to build DAESoftMax model...
# Finished at 12:33:42, duration in sec: 6
# 3.118725061416626
# tensor(0.1750)

# %%
buildModelMulti(ConvNet(), 0.001, 50, plot=True, save=True)
# Out:
# Starting at 17:12:28 to build ConvNet model...
# Finished at 17:14:12, duration in sec: 103

# %%
invertModel(ConvNet(), 0.01, 0.01, 50, plot=True, save=True)
# Out:
# Starting at 17:14:23 to invert ConvNet...
# Finished at 17:15:05, duration in sec: 42
# SSM: mean 4.16e-05, std 2.36e-05
# NRMSE: mean 6.93e+00, std 7.47e+00
