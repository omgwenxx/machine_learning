# %% [markdown]
# # Fifa 19
# Dataset used: [Fifa 19 dataset](https://www.kaggle.com/karangadiya/fifa19)
#
# Target Variable:
# - Wage: integer, in thousand €, not null

# %%
import pandas as pd
import seaborn as sns

# %%
# Read data from file
df = pd.read_csv("../data/fifa/fifa19.csv")
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
# drop unnecessary columns
df = df.drop(columns=["Unnamed: 0", "ID", "Photo", "Flag", "Club Logo", "Real Face"])
# drop other columns
df = df.drop(columns=["Name", "Release Clause"])

# %%
# drop goalkeepers because they have missing values for position stats
# and also rows with missing value for Position for same reason 

df = df[df["Position"] != "GK"]
df = df[~df["Position"].isnull()]

df = df[~df["Joined"].isnull()]

df = df[~df["Contract Valid Until"].isnull()]

# %%
df.head()
# Out:
#    Age Nationality  Overall  Potential                 Club    Value   Wage  \
# 0   31   Argentina       94         94         FC Barcelona  €110.5M  €565K
# 1   33    Portugal       94         94             Juventus     €77M  €405K
# 2   26      Brazil       92         93  Paris Saint-Germain  €118.5M  €290K
# 4   27     Belgium       91         92      Manchester City    €102M  €355K
# 5   27     Belgium       91         91              Chelsea     €93M  €340K
#
#    Special Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 0     2202           Left                       5.0        4.0          4.0
# 1     2228          Right                       5.0        4.0          5.0
# 2     2143          Right                       5.0        5.0          5.0
# 4     2281          Right                       4.0        5.0          4.0
# 5     2142          Right                       4.0        4.0          4.0
#
# ...

# %%
# reduce dataframe to subset to make manageable for polynomial regression
df_small1 = df.drop(columns=["Nationality", "Club", "Preferred Foot", "Work Rate", "Body Type", "Jersey Number", "Joined", "Contract Valid Until", "Loaned From"])
df_small2 = df[["Nationality", "Club", "Preferred Foot", "Work Rate", "Body Type", "Jersey Number", "Joined", "Contract Valid Until", "Loaned From", "Value", "Wage"]]

# %%
# reduce dataframe to subset to make manageable for polynomial regression
# df_small1 = df_small1.sample(n = 5000)
# df_small1.shape
# df_small2 = df_small2.sample(n = 5000)
# df_small2.shape

# %%
df.to_csv('../data/fifa/fifa19_df.csv', index=False)
df_small1.to_csv('../data/fifa/fifa19_dfsmall1.csv', index=False)
df_small2.to_csv('../data/fifa/fifa19_dfsmall2.csv', index=False)
